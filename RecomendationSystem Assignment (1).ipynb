# %%
import pandas as pd
df = pd.read_csv("anime.csv")
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
# Data Preprocessing:
# Load the dataset into a suitable data structure (e.g., pandas DataFrame).
# Handle missing values, if any.
# Explore the dataset to understand its structure and attributes.

import pandas as pd

# Load the dataset
df = pd.read_csv("anime.csv")

# Handle missing values (example: fill with mean for numerical columns)
numerical_cols = df.select_dtypes(include=['number']).columns
for col in numerical_cols:
    df[col] = df[col].fillna(df[col].mean())


# Explore the dataset
print(df.head())  # Display first 5 rows
print(df.info())  # Display data types and non-null counts
print(df.describe())  # Descriptive statistics for numerical columns
print(df.isnull().sum()) # Check the number of missing values in each column

# Example: Explore unique values of a categorical column
# print(df['genre'].unique())
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12294 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB
# None
#            anime_id        rating       members
# count  12294.000000  12294.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.017096  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.900000  2.250000e+02
# 50%    10260.500000      6.550000  1.550000e+03
# 75%    24794.500000      7.170000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06
# anime_id     0
# name         0
# genre       62
# type        25
# episodes     0
# rating       0
# members      0
# dtype: int64

# %%
# prompt: Feature Extraction:
# Decide on the features that will be used for computing similarity (e.g., genres, user ratings).
# Convert categorical features into numerical representations if necessary.
# Normalize numerical features if required

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming df is already loaded and preprocessed as in the previous code

# Feature Selection and Engineering
features = ['genre', 'rating', 'members']  # Example features

# Convert 'genre' (categorical) to numerical using one-hot encoding
df = pd.get_dummies(df, columns=['genre'], prefix='genre')

# Normalize numerical features (rating and members) using MinMaxScaler
scaler = MinMaxScaler()
df[['rating_scaled', 'members_scaled']] = scaler.fit_transform(df[['rating', 'members']])

# Create a feature matrix
feature_matrix = df[list(df.filter(regex='genre')) + ['rating_scaled', 'members_scaled']]
print(feature_matrix.head())
# Out:
#    genre_Action  genre_Action, Adventure  \
# 0         False                    False
# 1         False                    False
# 2         False                    False
# 3         False                    False
# 4         False                    False
#
#    genre_Action, Adventure, Cars, Comedy, Sci-Fi, Shounen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    genre_Action, Adventure, Cars, Mecha, Sci-Fi, Shounen, Sports  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    genre_Action, Adventure, Cars, Sci-Fi  genre_Action, Adventure, Comedy  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
#
#    genre_Action, Adventure, Comedy, Demons, Drama, Ecchi, Horror, Mystery, Romance, Sci-Fi  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    genre_Action, Adventure, Comedy, Demons, Fantasy, Magic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    genre_Action, Adventure, Comedy, Demons, Fantasy, Magic, Romance, Shounen, Supernatural  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    genre_Action, Adventure, Comedy, Demons, Fantasy, Martial Arts, Shounen, Super Power  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  genre_Slice of Life, Supernatural  genre_Space  genre_Sports  \
# 0  ...                              False        False         False
# 1  ...                              False        False         False
# 2  ...                              False        False         False
# 3  ...                              False        False         False
# 4  ...                              False        False         False
#
#    genre_Super Power, Supernatural, Vampire  genre_Supernatural  \
# 0                                     False               False
# 1                                     False               False
# 2                                     False               False
# 3                                     False               False
# 4                                     False               False
#
#    genre_Thriller  genre_Vampire  genre_Yaoi  rating_scaled  members_scaled
# 0           False          False       False       0.924370        0.197872
# 1           False          False       False       0.911164        0.782770
# 2           False          False       False       0.909964        0.112689
# 3           False          False       False       0.900360        0.664325
# 4           False          False       False       0.899160        0.149186
#
# [5 rows x 3266 columns]

# %%
#  Recommendation System:
# Design a function to recommend anime based on cosine similarity.
# Given a target anime, recommend a list of similar anime based on cosine similarity scores.
# Experiment with different threshold values for similarity scores to adjust the recommendation list size.

import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

def recommend_anime(target_anime, threshold=0.5):
    # Preprocess the data
    df['genre'] = df['genre'].fillna('')

    # Create a count vectorizer
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(df['genre'])

    # Calculate cosine similarity
    cosine_sim = cosine_similarity(count_matrix)

    # Get the index of the target anime
    try:
        target_index = df[df['name'] == target_anime].index[0]
    except IndexError:
        print(f"Anime '{target_anime}' not found in the dataset.")
        return []

    # Get similarity scores for the target anime
    similarity_scores = list(enumerate(cosine_sim[target_index]))

    # Sort the anime based on similarity scores
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

    # Recommend anime above the threshold
    recommendations = []
    for anime_index, score in similarity_scores:
        if score > threshold and anime_index != target_index:
            recommendations.append(
                (df['name'][anime_index], score)
            )
    return recommendations

# Example usage
recommendations = recommend_anime("Naruto", threshold=0.6)  # Adjust the threshold
if recommendations:
    print("Recommended Anime:")
    for anime, score in recommendations:
        print(f"- {anime} (Similarity Score: {score:.2f})")
else:
    print("No recommendations found for the specified anime and threshold.")
# Out:
# Recommended Anime:
# - Boruto: Naruto the Movie (Similarity Score: 1.00)
# - Naruto: Shippuuden (Similarity Score: 1.00)
# - Boruto: Naruto the Movie - Naruto ga Hokage ni Natta Hi (Similarity Score: 1.00)
# - Naruto x UT (Similarity Score: 1.00)
# - Naruto: Shippuuden Movie 4 - The Lost Tower (Similarity Score: 1.00)
# - Naruto: Shippuuden Movie 3 - Hi no Ishi wo Tsugu Mono (Similarity Score: 1.00)
# - Naruto Shippuuden: Sunny Side Battle (Similarity Score: 1.00)
# - Naruto Soyokazeden Movie: Naruto to Mashin to Mitsu no Onegai Dattebayo!! (Similarity Score: 1.00)
# - Kyutai Panic Adventure! (Similarity Score: 0.93)
# - Dragon Ball Z (Similarity Score: 0.88)
# - Dragon Ball Kai (2014) (Similarity Score: 0.88)
# - Dragon Ball Kai (Similarity Score: 0.88)
# - Medaka Box Abnormal (Similarity Score: 0.88)
# - Dragon Ball Z Movie 15: Fukkatsu no F (Similarity Score: 0.88)
# - Dragon Ball Super (Similarity Score: 0.88)
# - Medaka Box (Similarity Score: 0.88)
# - Tenjou Tenge (Similarity Score: 0.88)
# - Dragon Ball Z: Summer Vacation Special (Similarity Score: 0.88)
# - Dragon Ball Z: Atsumare! Gokuu World (Similarity Score: 0.88)
# - Dragon Ball GT: Goku Gaiden! Yuuki no Akashi wa Suushinchuu (Similarity Score: 0.88)
# - Dragon Ball Z Movie 11: Super Senshi Gekiha!! Katsu no wa Ore da (Similarity Score: 0.88)
# - The Last: Naruto the Movie (Similarity Score: 0.86)
# - Naruto: Shippuuden Movie 6 - Road to Ninja (Similarity Score: 0.86)
# - Rekka no Honoo (Similarity Score: 0.86)
# - Naruto: Honoo no Chuunin Shiken! Naruto vs. Konohamaru!! (Similarity Score: 0.86)
# - Street Fighter Zero The Animation (Similarity Score: 0.86)
# - Variable Geo (Similarity Score: 0.86)
# - Iron Virgin Jun (Similarity Score: 0.86)
# - Katekyo Hitman Reborn! (Similarity Score: 0.85)
# - Kurokami The Animation (Similarity Score: 0.85)
# - Project ARMS (Similarity Score: 0.85)
# - Kurokami: Tora to Tsubasa (Similarity Score: 0.85)
# - Kurokami: Intermission (Similarity Score: 0.85)
# - Wolverine (Similarity Score: 0.85)
# - Akai Hayate (Similarity Score: 0.85)
# - Battle Spirits: Ryuuko no Ken (Similarity Score: 0.85)
# - Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai (Similarity Score: 0.84)
# - Saint Seiya: The Lost Canvas - Meiou Shinwa 2 (Similarity Score: 0.80)
# - Saint Seiya: The Lost Canvas - Meiou Shinwa (Similarity Score: 0.80)
# - Dragon Ball (Similarity Score: 0.80)
# - Dragon Ball Z Movie 14: Kami to Kami (Similarity Score: 0.80)
# - Naruto: Shippuuden Movie 5 - Blood Prison (Similarity Score: 0.80)
# - Taboo Tattoo (Similarity Score: 0.80)
# - Dragon Ball: Episode of Bardock (Similarity Score: 0.80)
# - Boku no Hero Academia (Similarity Score: 0.77)
# - Shijou Saikyou no Deshi Kenichi (Similarity Score: 0.77)
# - Shijou Saikyou no Deshi Kenichi OVA (Similarity Score: 0.77)
# - Bleach (Similarity Score: 0.77)
# - Bleach Movie 4: Jigoku-hen (Similarity Score: 0.77)
# - Ranma ½: Akumu! Shunmin Kou (Similarity Score: 0.77)
# - Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu (Similarity Score: 0.77)
# - Hokuto no Ken 2 (Similarity Score: 0.77)
# - One Piece: Romance Dawn (Similarity Score: 0.77)
# - One Piece: Romance Dawn Story (Similarity Score: 0.77)
# - Sakigake!! Otokojuku (Similarity Score: 0.77)
# - Shijou Saikyou no Deshi Kenichi Specials (Similarity Score: 0.77)
# - Boku no Hero Academia: Jump Festa 2016 Special (Similarity Score: 0.77)
# - Muteki Kanban Musume (Similarity Score: 0.77)
# - Kenyuu Densetsu Yaiba (Similarity Score: 0.77)
# - Toriko: Jump Super Anime Tour 2009 Special (Similarity Score: 0.77)
# - Virtua Fighter (Similarity Score: 0.77)
# - Kakutou Bijin Wulong: Rebirth (Similarity Score: 0.77)
# - Sakigake!! Otokojuku Movie (Similarity Score: 0.77)
# - Toriko: Barbarian Ivy wo Hokaku Seyo! (Similarity Score: 0.77)
# - Yuu☆Yuu☆Hakusho Picture Drama (Similarity Score: 0.77)
# - Naruto: Takigakure no Shitou - Ore ga Eiyuu Dattebayo! (Similarity Score: 0.77)
# - Crayon Shin-chan Manatsu no Yoru ni Ora Sanjou! Arashi wo Yobu Den-O vs. Shin-O 60-bu Special!! (Similarity Score: 0.77)
# - Tatakae!! Ramenman (Similarity Score: 0.77)
# - Riki-Oh: Toukatsu Jigoku (Similarity Score: 0.77)
# - Getsumen To Heiki Mina Specials (Similarity Score: 0.77)
# - Ninku: Knife no Bohyou (Similarity Score: 0.77)
# - Gakuen Tokusou Hikaruon (Similarity Score: 0.77)
# - Riki-Oh 2: Horobi no Ko (Similarity Score: 0.77)
# - Machine Robo: Leina, The Legend of Wolf Blade (Similarity Score: 0.77)
# - Boku no Hero Academia 2nd Season (Similarity Score: 0.77)
# - Dragon Ball Z: Zenbu Misemasu Toshi Wasure Dragon Ball Z! (Similarity Score: 0.76)
# - Ben-To (Similarity Score: 0.76)
# - Street Fighter II: The Movie (Similarity Score: 0.76)
# - Koukou Tekken-den Tough (Similarity Score: 0.76)
# - Tiger &amp; Bunny Pilot (Similarity Score: 0.76)
# - Big Order (Similarity Score: 0.76)
# - Bulg-eunmae (Similarity Score: 0.76)
# - Big Order (TV) (Similarity Score: 0.76)
# - Kyutai Panic Adventure Returns! (Similarity Score: 0.76)
# - Baki (Similarity Score: 0.76)
# - Huang Feihong Yong Chuang Tianxia (Similarity Score: 0.76)
# - Mushibugyou (Similarity Score: 0.76)
# - Mushibugyou OVA (Similarity Score: 0.76)
# - Gatchaman (Similarity Score: 0.76)
# - Baoh Raihousha (Similarity Score: 0.76)
# - One Piece Film: Strong World Episode 0 (Similarity Score: 0.71)
# - One Piece: Episode of Luffy - Hand Island no Bouken (Similarity Score: 0.71)
# - Sengoku Basara Movie: The Last Party (Similarity Score: 0.71)
# - One Piece Movie 4: Dead End no Bouken (Similarity Score: 0.71)
# - Sengoku Basara Two (Similarity Score: 0.71)
# - One Piece Movie 9: Episode of Chopper Plus - Fuyu ni Saku, Kiseki no Sakura (Similarity Score: 0.71)
# - Yozakura Quartet: Tsuki ni Naku (Similarity Score: 0.71)
# - Yozakura Quartet: Hana no Uta (Similarity Score: 0.71)
# - Sengoku Basara (Similarity Score: 0.71)
# - One Piece: Adventure of Nebulandia (Similarity Score: 0.71)
# - Ranma ½: Chou Musabetsu Kessen! Ranma Team vs. Densetsu no Houou (Similarity Score: 0.71)
# - Yozakura Quartet: Hoshi no Umi (Similarity Score: 0.71)
# - One Piece Movie 5: Norowareta Seiken (Similarity Score: 0.71)
# - One Piece: Umi no Heso no Daibouken-hen (Similarity Score: 0.71)
# - One Piece: Oounabara ni Hirake! Dekkai Dekkai Chichi no Yume! (Similarity Score: 0.71)
# - One Piece: Glorious Island (Similarity Score: 0.71)
# - One Piece Recap (Similarity Score: 0.71)
# - One Piece Movie 2: Nejimaki-jima no Daibouken (Similarity Score: 0.71)
# - One Piece Movie 1 (Similarity Score: 0.71)
# - Project ARMS: The 2nd Chapter (Similarity Score: 0.71)
# - One Piece Movie 3: Chinjuu-jima no Chopper Oukoku (Similarity Score: 0.71)
# - Dragon Ball Movie 1: Shen Long no Densetsu (Similarity Score: 0.71)
# - One Piece Film: Gold Episode 0 - 711 ver. (Similarity Score: 0.71)
# - Code:Breaker (Similarity Score: 0.71)
# - Ikkitousen: Dragon Destiny (Similarity Score: 0.71)
# - Ikkitousen: Great Guardians (Similarity Score: 0.71)
# - Naruto: Dai Katsugeki!! Yuki Hime Shinobu Houjou Dattebayo! Special: Konoha Annual Sports Festival (Similarity Score: 0.71)
# - Yozakura Quartet (Similarity Score: 0.71)
# - Ikkitousen: Xtreme Xecutor (Similarity Score: 0.71)
# - Sengoku Basara: Judge End (Similarity Score: 0.71)
# - One Piece: Taose! Kaizoku Ganzack (Similarity Score: 0.71)
# - Ikkitousen: Shuugaku Toushi Keppuuroku (Similarity Score: 0.71)
# - Samurai Spirits 2: Asura Zanmaden (Similarity Score: 0.71)
# - Ninku (Movie) (Similarity Score: 0.71)
# - Shin Hurricane Polymar (Similarity Score: 0.71)
# - Battle Royal High School (Similarity Score: 0.71)
# - Hunter x Hunter (2011) (Similarity Score: 0.68)
# - Hunter x Hunter (Similarity Score: 0.68)
# - Hunter x Hunter OVA (Similarity Score: 0.68)
# - Hunter x Hunter: Greed Island Final (Similarity Score: 0.68)
# - Hunter x Hunter: Greed Island (Similarity Score: 0.68)
# - Kill la Kill (Similarity Score: 0.68)
# - Tiger &amp; Bunny (Similarity Score: 0.68)
# - D.Gray-man Hallow (Similarity Score: 0.68)
# - Tiger &amp; Bunny Movie 2: The Rising (Similarity Score: 0.68)
# - Shin Mazinger Shougeki! Z-hen (Similarity Score: 0.68)
# - Sexy Commando Gaiden: Sugoiyo!! Masaru-san (Similarity Score: 0.68)
# - Ranma ½ OVA (Similarity Score: 0.68)
# - Kill la Kill Special (Similarity Score: 0.68)
# - Saint Seiya: Meiou Hades Elysion-hen (Similarity Score: 0.68)
# - Tiger &amp; Bunny Movie 1: The Beginning (Similarity Score: 0.68)
# - Grappler Baki: Saidai Tournament-hen (Similarity Score: 0.68)
# - Naruto: Shippuuden Movie 2 - Kizuna (Similarity Score: 0.68)
# - Hunter x Hunter Movie: Phantom Rouge (Similarity Score: 0.68)
# - Hunter x Hunter Pilot (Similarity Score: 0.68)
# - Hunter x Hunter Movie: The Last Mission (Similarity Score: 0.68)
# - Air Master (Similarity Score: 0.68)
# - Kamen no Maid Guy (Similarity Score: 0.68)
# - Dragon Ball Specials (Similarity Score: 0.68)
# - Sasuke (Similarity Score: 0.68)
# - Sexy Commando Gaiden: Sugoiyo!! Masaru-san Specials (Similarity Score: 0.68)
# - Souten no Ken Specials (Similarity Score: 0.68)
# - Onikirimaru (Similarity Score: 0.68)
# - Tiger &amp; Bunny Recaps (Similarity Score: 0.68)
# - Street Fighter II: Yomigaeru Fujiwara-Kyou - Toki wo Kaketa Fighter-tachi (Similarity Score: 0.68)
# - Giga Tribe (Similarity Score: 0.68)
# - Heungnyongwanggwa Bihodongja (Similarity Score: 0.68)
# - Nano Invaders (Similarity Score: 0.68)
# - Ninja Hattori-kun Plus Perman: Chounouryoku Wars (Similarity Score: 0.68)
# - Taegeugsonyeon Huin Dogsuli (Similarity Score: 0.68)
# - Tatakae!! Ramenman (Movie) (Similarity Score: 0.68)
# - Tiger &amp; Bunny: Too Many Cooks Spoil the Broth (Similarity Score: 0.68)
# - Ultraman Graffiti (Similarity Score: 0.68)
# - Sexy Sailor Soldiers (Similarity Score: 0.68)
# - One Piece (Similarity Score: 0.67)
# - Yuu☆Yuu☆Hakusho (Similarity Score: 0.67)
# - One Piece: Episode of Merry - Mou Hitori no Nakama no Monogatari (Similarity Score: 0.67)
# - One Piece: Episode of Nami - Koukaishi no Namida to Nakama no Kizuna (Similarity Score: 0.67)
# - One Piece: Episode of Sabo - 3 Kyoudai no Kizuna Kiseki no Saikai to Uketsugareru Ishi (Similarity Score: 0.67)
# - GetBackers (Similarity Score: 0.67)
# - Dragon Ball Kai: Mirai ni Heiwa wo! Goku no Tamashii yo Eien ni (Similarity Score: 0.67)
# - Yuusha Shirei Dagwon (Similarity Score: 0.67)
# - Kyattou Ninden Teyandee (Similarity Score: 0.67)
# - Kinnikuman II Sei: Ultimate Muscle 2 (Similarity Score: 0.67)
# - Kinnikuman II Sei: Ultimate Muscle (Similarity Score: 0.67)
# - Kinnikuman II Sei (Similarity Score: 0.67)
# - Code:Breaker OVA (Similarity Score: 0.67)
# - Ikkitousen: Extravaganza Epoch (Similarity Score: 0.67)
# - Maken-Ki! OVA (Similarity Score: 0.67)
# - Honoo no Tenkousei (Similarity Score: 0.67)
# - Maken-Ki! (Similarity Score: 0.67)
# - Tokyo ESP (Similarity Score: 0.67)
# - Maken-Ki! Two (Similarity Score: 0.67)
# - Arcade Gamer Fubuki (Similarity Score: 0.67)
# - Ninja Hattori-kun Plus Perman: Ninja Kaijuu Jippou tai Miracle Tamago (Similarity Score: 0.67)
# - Hokuto no Ken: Toki-den (Similarity Score: 0.65)
# - Aoharu x Kikanjuu: Kemono-tachi no Senjou da na! (Similarity Score: 0.65)
# - Black Cat Special (Similarity Score: 0.65)
# - Ansatsu Kyoushitsu (Similarity Score: 0.65)
# - Katekyo Hitman Reborn! x ēlDLIVE Special (Similarity Score: 0.65)
# - Shounan Bakusouzoku (Similarity Score: 0.65)
# - Kizuna Ichigeki (Similarity Score: 0.65)
# - Lupin III: Pilot Film (Similarity Score: 0.65)
# - Hokuto no Ken: Legend of Heroes (Similarity Score: 0.65)
# - 009 Re:Cyborg x Zip (Similarity Score: 0.65)
# - Abashiri Ikka (Similarity Score: 0.65)
# - Toushinden (Similarity Score: 0.65)
# - Double Hard (Similarity Score: 0.65)
# - Feng Ji Yun Nu (Similarity Score: 0.65)
# - Geori-eui Mubeopja (Similarity Score: 0.65)
# - Hulu Xiongdi (Similarity Score: 0.65)
# - Pyun Pyun Maru (Similarity Score: 0.65)
# - Sakuran Boy DT (Similarity Score: 0.65)
# - Shin Karate Jigoku-hen (Similarity Score: 0.65)
# - Shinken Densetsu: Tight Road (Similarity Score: 0.65)
# - Ultra B (Similarity Score: 0.65)
# - THE REFLECTION (Similarity Score: 0.65)
# - Dragon Ball Movie 4: Saikyou e no Michi (Similarity Score: 0.63)
# - Shadow Skill: Eigi (Similarity Score: 0.63)
# - Dragon Ball Movie 3: Makafushigi Daibouken (Similarity Score: 0.63)
# - Dragon Ball: Super Saiya-jin Zetsumetsu Keikaku (Similarity Score: 0.63)
# - Dragon Ball Movie 2: Majinjou no Nemuri Hime (Similarity Score: 0.63)
# - Maji de Watashi ni Koi Shinasai! (Similarity Score: 0.63)
# - To Heart: Remember My Memories Specials (Similarity Score: 0.63)
# - Shingeki no Kyojin (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha: The Movie 2nd A&#039;s (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha A&#039;s (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha: The Movie 1st (Similarity Score: 0.62)
# - Shingeki no Kyojin OVA (Similarity Score: 0.62)
# - Tokyo Ravens (Similarity Score: 0.62)
# - Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha StrikerS (Similarity Score: 0.62)
# - Shingeki no Kyojin Movie 1: Guren no Yumiya (Similarity Score: 0.62)
# - Mutsu Enmei Ryuu Gaiden: Shura no Toki (Similarity Score: 0.62)
# - Sekirei: Pure Engagement (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha (Similarity Score: 0.62)
# - Tekken Chinmi (Similarity Score: 0.62)
# - Sekirei (Similarity Score: 0.62)
# - Shin Hokuto no Ken (Similarity Score: 0.62)
# - Kiddy GiRL-AND (Similarity Score: 0.62)
# - Shingeki no Kyojin: Ano Hi Kara (Similarity Score: 0.62)
# - Fatal Fury 2: The New Battle (Similarity Score: 0.62)
# - Tottemo! Luckyman (Similarity Score: 0.62)
# - Kamen Rider Den-O: Imagin Anime 2 (Similarity Score: 0.62)
# - Yume Senshi Wingman (Similarity Score: 0.62)
# - Ikkitousen: Dragon Destiny Specials (Similarity Score: 0.62)
# - Kamen Rider Den-O: Imagin Anime (Similarity Score: 0.62)
# - Beast Wars Neo (Similarity Score: 0.62)
# - Ikkitousen (Similarity Score: 0.62)
# - Kamen Rider Den-O: Imagin Anime 3 (Similarity Score: 0.62)
# - Mini Hama: Minimum Hamatora (Similarity Score: 0.62)
# - Yumeria (Similarity Score: 0.62)
# - Psychic Force (Similarity Score: 0.62)
# - Mirai Kara Kita Shounen Super Jetter (Similarity Score: 0.62)
# - Momotaros no Natsuyasumi (Similarity Score: 0.62)
# - Ogami Matsugorou (Similarity Score: 0.62)
# - Qin Shiming Yue Zhi: Guoqing Tebie Pian (Similarity Score: 0.62)
# - Shingeki no Kyojin Season 2 (Similarity Score: 0.62)
# - Mahou Shoujo Lyrical Nanoha Reflection (Similarity Score: 0.62)

# %%
#  Evaluation:
# Split the dataset into training and testing sets.
# Evaluate the recommendation system using appropriate metrics such as precision, recall, and F1-score.
# Analyze the performance of the recommendation system and identify areas of improvement.

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

import pandas as pd
df = pd.read_csv("anime.csv")

# Feature Engineering (Example:  I'll likely need more sophisticated features)
# For this example, we'll use 'genre' as a simple feature.  In a real-world scenario,
# you would use more relevant features like user ratings, watch history, etc.
df['genre_list'] = df['genre'].str.split(', ')

# Create user-item interaction matrix (replace with your actual interaction data)
# This is a placeholder example;  adapt to your data structure.
#  For example: user_anime_ratings
user_anime_ratings = pd.DataFrame({
    'user_id': [1, 1, 2, 2, 3, 3],
    'anime_id': [1, 2, 1, 3, 2, 3],
    'rating': [5, 4, 3, 5, 2, 4]  # Example ratings
})

# Split data
train_data, test_data = train_test_split(user_anime_ratings, test_size=0.2, random_state=42)

# Placeholder for a recommendation model (REPLACE THIS WITH YOUR ACTUAL MODEL)
def simple_recommendation_model(user_id, train_data):
    # Example: Recommend the top 2 most frequently rated anime
    recommendations = train_data.groupby('anime_id')['rating'].count().sort_values(ascending=False).head(2).index.tolist()
    return recommendations

# Make predictions on the test set
predictions = []
actual = []
for user_id, anime_id, rating in test_data.values:
  recommendations = simple_recommendation_model(user_id, train_data)
  predictions.append(anime_id in recommendations)  # Check if the actual anime was recommended
  actual.append(1)  # Treat as relevant because it was rated


# Calculate evaluation metrics
precision = precision_score(actual, predictions)
recall = recall_score(actual, predictions)
f1 = f1_score(actual, predictions)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

# Analysis and Areas of Improvement:
# 1. Feature Engineering:  Explore user demographics, watch history, reviews, and other features.
# 2. Model Selection: Try different recommendation algorithms (collaborative filtering, content-based filtering, hybrid).
# 3. Hyperparameter Tuning: Optimize parameters for your chosen model.
# 4. Data Quality:  Clean and preprocess data, handle missing values appropriately.
# 5. Cold-Start Problem:  Address recommendations for new users or anime with limited data.
# 6. Evaluation Metrics: Consider more comprehensive evaluation metrics like NDCG or MAP.
# Out:
# Precision: 1.0
# Recall: 0.5
# F1-score: 0.6666666666666666

# %%
#Interview Questions:
# 1. Can you explain the difference between user-based and item-based collaborative filtering?

def explain_collaborative_filtering():
    """Explains collaborative filtering and its types."""
    print("Collaborative filtering is a recommendation technique that predicts user preferences based on the preferences of similar users or items.")
    print("It leverages the 'wisdom of the crowd' – if users A and B have similar tastes in the past, then A is likely to enjoy what B liked recently.")
    print("\nThere are two main types:")
    print("\n1. User-based Collaborative Filtering:")
    print("   - Finds users with similar tastes to a target user.  The system identifies users with similar rating patterns for items they've both interacted with (e.g., movies, products).")
    print("   - Predicts ratings for items based on the ratings of similar users.  It aggregates the ratings of those similar users for items the target user hasn't yet rated, providing a prediction of how the target user might rate them.")
    print("   - Pros: Relatively simple to implement.")
    print("   - Cons: Can suffer from scalability issues as the user base grows (comparing a user to every other user becomes computationally expensive). Susceptible to popularity bias (over-recommending popular items because many similar users have interacted with them).  Also suffers from the 'cold start' problem for new users with limited interaction history.")

    print("\n2. Item-based Collaborative Filtering:")
    print("   - Finds items similar to items a target user has liked. It identifies items that are frequently rated similarly by users.")
    print("   - Predicts ratings for new items based on how similar items have been rated.  If a user liked item A, and item B is similar to A (based on how other users rated them), the system predicts the user will also like item B.")
    print("   - Pros: More scalable compared to user-based filtering (item similarity is relatively static). Less susceptible to changes in user behavior (user profiles can change, but item similarity is more stable).")
    print("   - Cons: Might not capture diverse user preferences as well as user-based (doesn't consider individual user nuances as much). Also suffers from the 'cold start' problem for new items with limited interaction history.")

def answer_interview_questions():
    explain_collaborative_filtering()
    

answer_interview_questions()
# Out:
# Collaborative filtering is a recommendation technique that predicts user preferences based on the preferences of similar users or items.
# It leverages the 'wisdom of the crowd' – if users A and B have similar tastes in the past, then A is likely to enjoy what B liked recently.
#
# There are two main types:
#
# 1. User-based Collaborative Filtering:
#    - Finds users with similar tastes to a target user.  The system identifies users with similar rating patterns for items they've both interacted with (e.g., movies, products).
#    - Predicts ratings for items based on the ratings of similar users.  It aggregates the ratings of those similar users for items the target user hasn't yet rated, providing a prediction of how the target user might rate them.
#    - Pros: Relatively simple to implement.
#    - Cons: Can suffer from scalability issues as the user base grows (comparing a user to every other user becomes computationally expensive). Susceptible to popularity bias (over-recommending popular items because many similar users have interacted with them).  Also suffers from the 'cold start' problem for new users with limited interaction history.
#
# 2. Item-based Collaborative Filtering:
#    - Finds items similar to items a target user has liked. It identifies items that are frequently rated similarly by users.
#    - Predicts ratings for new items based on how similar items have been rated.  If a user liked item A, and item B is similar to A (based on how other users rated them), the system predicts the user will also like item B.
#    - Pros: More scalable compared to user-based filtering (item similarity is relatively static). Less susceptible to changes in user behavior (user profiles can change, but item similarity is more stable).
#    - Cons: Might not capture diverse user preferences as well as user-based (doesn't consider individual user nuances as much). Also suffers from the 'cold start' problem for new items with limited interaction history.

# %%
#  2. What is collaborative filtering, and how does it work?

def explain_collaborative_filtering():
    """Explains collaborative filtering and its types."""
    print("Collaborative filtering is a recommendation technique that predicts user preferences based on the preferences of similar users or items.")
    print("It leverages the 'wisdom of the crowd' – if users A and B have similar tastes in the past, then A is likely to enjoy what B liked recently.")
    print("\nThere are two main types:")
    print("\n1. User-based Collaborative Filtering:")
    print("   - Finds users with similar tastes to a target user.  The system identifies users with similar rating patterns for items they've both interacted with (e.g., movies, products).")
    print("   - Predicts ratings for items based on the ratings of similar users.  It aggregates the ratings of those similar users for items the target user hasn't yet rated, providing a prediction of how the target user might rate them.")
    print("   - Pros: Relatively simple to implement.")
    print("   - Cons: Can suffer from scalability issues as the user base grows (comparing a user to every other user becomes computationally expensive). Susceptible to popularity bias (over-recommending popular items because many similar users have interacted with them).  Also suffers from the 'cold start' problem for new users with limited interaction history.")

    print("\n2. Item-based Collaborative Filtering:")
    print("   - Finds items similar to items a target user has liked. It identifies items that are frequently rated similarly by users.")
    print("   - Predicts ratings for new items based on how similar items have been rated.  If a user liked item A, and item B is similar to A (based on how other users rated them), the system predicts the user will also like item B.")
    print("   - Pros: More scalable compared to user-based filtering (item similarity is relatively static). Less susceptible to changes in user behavior (user profiles can change, but item similarity is more stable).")
    print("   - Cons: Might not capture diverse user preferences as well as user-based (doesn't consider individual user nuances as much). Also suffers from the 'cold start' problem for new items with limited interaction history.")

# %%
# p2. What is collaborative filtering, and how does it work?

def explain_collaborative_filtering():
    """Explains collaborative filtering and its types."""
    print("Collaborative filtering is a recommendation technique that predicts user preferences based on the preferences of similar users or items.")
    print("It leverages the 'wisdom of the crowd' – if users A and B have similar tastes in the past, then A is likely to enjoy what B liked recently.")
    print("\nThere are two main types:")
    print("\n1. User-based Collaborative Filtering:")
    print("   - Finds users with similar tastes to a target user.  The system identifies users with similar rating patterns for items they've both interacted with (e.g., movies, products).")
    print("   - Predicts ratings for items based on the ratings of similar users.  It aggregates the ratings of those similar users for items the target user hasn't yet rated, providing a prediction of how the target user might rate them.")
    print("   - Pros: Relatively simple to implement.")
    print("   - Cons: Can suffer from scalability issues as the user base grows (comparing a user to every other user becomes computationally expensive). Susceptible to popularity bias (over-recommending popular items because many similar users have interacted with them).  Also suffers from the 'cold start' problem for new users with limited interaction history.")

    print("\n2. Item-based Collaborative Filtering:")
    print("   - Finds items similar to items a target user has liked. It identifies items that are frequently rated similarly by users.")
    print("   - Predicts ratings for new items based on how similar items have been rated.  If a user liked item A, and item B is similar to A (based on how other users rated them), the system predicts the user will also like item B.")
    print("   - Pros: More scalable compared to user-based filtering (item similarity is relatively static). Less susceptible to changes in user behavior (user profiles can change, but item similarity is more stable).")
    print("   - Cons: Might not capture diverse user preferences as well as user-based (doesn't consider individual user nuances as much). Also suffers from the 'cold start' problem for new items with limited interaction history.")

def answer_interview_questions():
    explain_collaborative_filtering()
    

answer_interview_questions()
# Out:
# Collaborative filtering is a recommendation technique that predicts user preferences based on the preferences of similar users or items.
# It leverages the 'wisdom of the crowd' – if users A and B have similar tastes in the past, then A is likely to enjoy what B liked recently.
#
# There are two main types:
#
# 1. User-based Collaborative Filtering:
#    - Finds users with similar tastes to a target user.  The system identifies users with similar rating patterns for items they've both interacted with (e.g., movies, products).
#    - Predicts ratings for items based on the ratings of similar users.  It aggregates the ratings of those similar users for items the target user hasn't yet rated, providing a prediction of how the target user might rate them.
#    - Pros: Relatively simple to implement.
#    - Cons: Can suffer from scalability issues as the user base grows (comparing a user to every other user becomes computationally expensive). Susceptible to popularity bias (over-recommending popular items because many similar users have interacted with them).  Also suffers from the 'cold start' problem for new users with limited interaction history.
#
# 2. Item-based Collaborative Filtering:
#    - Finds items similar to items a target user has liked. It identifies items that are frequently rated similarly by users.
#    - Predicts ratings for new items based on how similar items have been rated.  If a user liked item A, and item B is similar to A (based on how other users rated them), the system predicts the user will also like item B.
#    - Pros: More scalable compared to user-based filtering (item similarity is relatively static). Less susceptible to changes in user behavior (user profiles can change, but item similarity is more stable).
#    - Cons: Might not capture diverse user preferences as well as user-based (doesn't consider individual user nuances as much). Also suffers from the 'cold start' problem for new items with limited interaction history.
